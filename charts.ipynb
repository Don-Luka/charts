# %% [markdown]
# ### Charts

# %%
import numpy as np
import pandas as pd
import xlsxwriter

# %% [markdown]
# Wczytaj do Pandas bazę najlepiej sprzedających się albumów wszechczasów.

# %%
data = pd.read_html(
    'https://www.officialcharts.com/chart-news/the-best-selling-albums-of-all-time-on-the-official-uk-chart__15551', 
    header=0)

# %%
charts = data[0]
charts
# Out:
#     POS                                   TITLE                    ARTIST  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# 12   13                           BACK TO BLACK             AMY WINEHOUSE
# 13   14                                   STARS                SIMPLY RED
# 14   15                            COME ON OVER              SHANIA TWAIN
# 15   16                                  LEGEND  BOB MARLEY & THE WAILERS
# 16   17                          BACK TO BEDLAM               JAMES BLUNT
# 17   18                             URBAN HYMNS                     VERVE
# 18   19                         BAT OUT OF HELL                 MEAT LOAF
# 19   20                                       1                   BEATLES
# 20   21              BRIDGE OVER TROUBLED WATER         SIMON & GARFUNKEL
# 21   22                           DIRTY DANCING       ORIGINAL SOUNDTRACK
# 22   23                                  SPIRIT               LEONA LEWIS
# 23   24                              CRAZY LOVE             MICHAEL BUBLE
# 24   25                                NO ANGEL                      DIDO
# 25   26                            WHITE LADDER                DAVID GRAY
# 26   27                                      25                     ADELE
# 27   28                         TALK ON CORNERS                     CORRS
# 28   29                                   SPICE               SPICE GIRLS
# 29   30                                THE FAME                 LADY GAGA
# 30   31             A RUSH OF BLOOD TO THE HEAD                  COLDPLAY
# 31   32                           LIFE FOR RENT                      DIDO
# 32   33                       ONLY BY THE NIGHT             KINGS OF LEON
# 33   34                         BEAUTIFUL WORLD                 TAKE THAT
# 34   35                         HOPES AND FEARS                     KEANE
# 35   36                         THE JOSHUA TREE                        U2
# 36   37                   THE WAR OF THE WORLDS                JEFF WAYNE
# 37   38                         SCISSOR SISTERS           SCISSOR SISTERS
# 38   39                           BUT SERIOUSLY              PHIL COLLINS
# 39   40                                     X&Y                  COLDPLAY
# 40   41                      JAGGED LITTLE PILL         ALANIS MORISSETTE
# 41   42                           TUBULAR BELLS             MIKE OLDFIELD
# 42   43                             THE MAN WHO                    TRAVIS
# 43   44                           TRACY CHAPMAN             TRACY CHAPMAN
# 44   45                              PARACHUTES                  COLDPLAY
# 45   46                           GREATEST HITS                      ABBA
# 46   47                                  GREASE       ORIGINAL SOUNDTRACK
# 47   48                 I'VE BEEN EXPECTING YOU           ROBBIE WILLIAMS
# 48   49                                       X                ED SHEERAN
# 49   50                       COME AWAY WITH ME               NORAH JONES
# 50   51                               GRACELAND                PAUL SIMON
# 51   52                      THE SOUND OF MUSIC   ORIGINAL CAST RECORDING
# 52   53        LADIES & GENTLEMEN - THE BEST OF            GEORGE MICHAEL
# 53   54                      TANGO IN THE NIGHT             FLEETWOOD MAC
# 54   55                 THE MARSHALL MATHERS LP                    EMINEM
# 55   56               SWING WHEN YOU'RE WINNING           ROBBIE WILLIAMS
# 56   57                                PROGRESS                 TAKE THAT
# 57   58                               EYES OPEN               SNOW PATROL
# 58   59  NEVER FORGET - THE ULTIMATE COLLECTION                 TAKE THAT
# 59   60                AUTOMATIC FOR THE PEOPLE                       REM
#
#     YEAR  HIGH POSN
# 0   1981          1
# 1   1992          1
# 2   1967          1
# 3   2011          1
# 4   1995          1
# 5   1982          1
# 6   1973          2
# 7   1985          1
# 8   1987          1
# 9   1991          1
# 10  1977          1
# 11  1990          1
# 12  2006          1
# 13  1991          1
# 14  1997          1
# 15  1984          1
# 16  2004          1
# 17  1997          1
# 18  1977          9
# 19  2000          1
# 20  1970          1
# 21  1987          4
# 22  2007          1
# 23  2009          1
# 24  2000          1
# 25  1998          1
# 26  2015          1
# 27  1997          1
# 28  1996          1
# 29  2008          1
# 30  2002          1
# 31  2003          1
# 32  2008          1
# 33  2006          1
# 34  2004          1
# 35  1987          1
# 36  1978          5
# 37  2004          1
# 38  1989          1
# 39  2005          1
# 40  1995          1
# 41  1973          1
# 42  1999          1
# 43  1988          1
# 44  2000          1
# 45  1975          1
# 46  1977          1
# 47  1998          1
# 48  2014          1
# 49  2002          1
# 50  1986          1
# 51  1965          1
# 52  1998          1
# 53  1987          1
# 54  2000          1
# 55  2001          1
# 56  2010          1
# 57  2006          1
# 58  2005          2
# 59  1992          1

# %%
charts.columns
# Out:
# Index(['POS', 'TITLE', 'ARTIST', 'YEAR', 'HIGH POSN'], dtype='object')

# %% [markdown]
# Zamień nagłówki kolumn na polskie odpowiedniki: ['TYTUŁ','ARTYSTA','ROK','MAX POZ']

# %%
charts.rename(
    columns = {
        'POS': 'POZYCJA', 
        'TITLE': 'TYTUŁ', 
        'ARTIST': 'ARTYSTA', 
        'YEAR': 'ROK', 
        'HIGH POSN': 'MAX POZ'
    }
    ,inplace=True)

# %%
charts.head()
# Out:
#    POZYCJA                                 TYTUŁ  ARTYSTA   ROK  MAX POZ
# 0        1                         GREATEST HITS    QUEEN  1981        1
# 1        2                  GOLD - GREATEST HITS     ABBA  1992        1
# 2        3  SGT PEPPER'S LONELY HEARTS CLUB BAND  BEATLES  1967        1
# 3        4                                    21    ADELE  2011        1
# 4        5        WHAT'S THE STORY MORNING GLORY    OASIS  1995        1

# %% [markdown]
# Ilu pojedynczych artystów znajduje się na liście?

# %%
number_of_unique_artists = len(charts['ARTYSTA'].unique())
number_of_unique_artists
# Out:
# 47

# %% [markdown]
# Które zespoły pojawiają się najczęściej na liście?

# %%
most_frequent_artists = charts['ARTYSTA'].value_counts().sort_values(ascending=False)

# %%
most_frequent_artists.head()
# Out:
# ARTYSTA
# COLDPLAY     3
# TAKE THAT    3
# QUEEN        2
# ADELE        2
# BEATLES      2
# Name: count, dtype: int64

# %%
most_frequent_artist = charts['ARTYSTA'].value_counts().index[0]
most_frequent_artist
# Out:
# 'COLDPLAY'

# %% [markdown]
# Zmień nagłówki kolumn, tak aby każdy z nich rozpoczynał się od wielkiej litery, a pozostałe były wprowadzone małymi literami.

# %%
charts.columns = charts.columns.str.capitalize()

# %%
charts.columns
# Out:
# Index(['Pozycja', 'Tytuł', 'Artysta', 'Rok', 'Max poz'], dtype='object')

# %%
charts.head()
# Out:
#    Pozycja                                 Tytuł  Artysta   Rok  Max poz
# 0        1                         GREATEST HITS    QUEEN  1981        1
# 1        2                  GOLD - GREATEST HITS     ABBA  1992        1
# 2        3  SGT PEPPER'S LONELY HEARTS CLUB BAND  BEATLES  1967        1
# 3        4                                    21    ADELE  2011        1
# 4        5        WHAT'S THE STORY MORNING GLORY    OASIS  1995        1

# %% [markdown]
# Wyrzuć z tabeli kolumnę ‘Max Poz’.

# %%
charts.drop(columns=['Max poz'], inplace=True)
charts.columns
# Out:
# Index(['Pozycja', 'Tytuł', 'Artysta', 'Rok'], dtype='object')

# %%
charts.head()
# Out:
#    Pozycja                                 Tytuł  Artysta   Rok
# 0        1                         GREATEST HITS    QUEEN  1981
# 1        2                  GOLD - GREATEST HITS     ABBA  1992
# 2        3  SGT PEPPER'S LONELY HEARTS CLUB BAND  BEATLES  1967
# 3        4                                    21    ADELE  2011
# 4        5        WHAT'S THE STORY MORNING GLORY    OASIS  1995

# %% [markdown]
# W którym roku wyszło najwięcej albumów znajdujących się na liście?

# %%
most_frequent_years = charts['Rok'].value_counts()
most_frequent_year = most_frequent_years.index[0]
most_frequent_year
# Out:
# 2000

# %% [markdown]
# Ile albumów wydanych między 1960 a 1990 rokiem włącznie znajduje się na liście?

# %%
albums_between_1960_1990 = charts[(charts['Rok'] >= 1960) & (charts['Rok'] <= 1990)].shape[0]
albums_between_1960_1990
# Out:
# 22

# %% [markdown]
# W którym roku wydany został najmłodszy album na liście?

# %%
latest_album_year = charts['Rok'].max()
latest_album_year
# Out:
# 2015

# %% [markdown]
# Przygotuj listę najwcześniej wydanych albumów każdego artysty, który znalazł się na liście.

# %%
debuts = charts.copy()
def answer():
    debuts.sort_values(by = 'Rok', inplace=True)
    debuts.shape[0]
    debuts.drop_duplicates(subset = 'Artysta', inplace = True)
    return debuts

# %%
debuts = answer()
debuts.reset_index(inplace=True)
debuts[['Artysta','Tytuł']]
# Out:
#                      Artysta                                   Tytuł
# 0    ORIGINAL CAST RECORDING                      THE SOUND OF MUSIC
# 1                    BEATLES    SGT PEPPER'S LONELY HEARTS CLUB BAND
# 2          SIMON & GARFUNKEL              BRIDGE OVER TROUBLED WATER
# 3                 PINK FLOYD               THE DARK SIDE OF THE MOON
# 4              MIKE OLDFIELD                           TUBULAR BELLS
# 5                       ABBA                           GREATEST HITS
# 6                  MEAT LOAF                         BAT OUT OF HELL
# 7              FLEETWOOD MAC                                 RUMOURS
# 8        ORIGINAL SOUNDTRACK                                  GREASE
# 9                 JEFF WAYNE                   THE WAR OF THE WORLDS
# 10                     QUEEN                           GREATEST HITS
# 11           MICHAEL JACKSON                                THRILLER
# 12  BOB MARLEY & THE WAILERS                                  LEGEND
# 13              DIRE STRAITS                        BROTHERS IN ARMS
# 14                PAUL SIMON                               GRACELAND
# 15                        U2                         THE JOSHUA TREE
# 16             TRACY CHAPMAN                           TRACY CHAPMAN
# 17              PHIL COLLINS                           BUT SERIOUSLY
# 18                   MADONNA               THE IMMACULATE COLLECTION
# 19                SIMPLY RED                                   STARS
# 20                       REM                AUTOMATIC FOR THE PEOPLE
# 21                     OASIS          WHAT'S THE STORY MORNING GLORY
# 22         ALANIS MORISSETTE                      JAGGED LITTLE PILL
# 23               SPICE GIRLS                                   SPICE
# 24                     CORRS                         TALK ON CORNERS
# 25              SHANIA TWAIN                            COME ON OVER
# 26                     VERVE                             URBAN HYMNS
# 27                DAVID GRAY                            WHITE LADDER
# 28            GEORGE MICHAEL        LADIES & GENTLEMEN - THE BEST OF
# 29           ROBBIE WILLIAMS                 I'VE BEEN EXPECTING YOU
# 30                    TRAVIS                             THE MAN WHO
# 31                      DIDO                                NO ANGEL
# 32                  COLDPLAY                              PARACHUTES
# 33                    EMINEM                 THE MARSHALL MATHERS LP
# 34               NORAH JONES                       COME AWAY WITH ME
# 35           SCISSOR SISTERS                         SCISSOR SISTERS
# 36                     KEANE                         HOPES AND FEARS
# 37               JAMES BLUNT                          BACK TO BEDLAM
# 38                 TAKE THAT  NEVER FORGET - THE ULTIMATE COLLECTION
# 39               SNOW PATROL                               EYES OPEN
# 40             AMY WINEHOUSE                           BACK TO BLACK
# 41               LEONA LEWIS                                  SPIRIT
# 42             KINGS OF LEON                       ONLY BY THE NIGHT
# 43                 LADY GAGA                                THE FAME
# 44             MICHAEL BUBLE                              CRAZY LOVE
# 45                     ADELE                                      21
# 46                ED SHEERAN                                       X

# %%
debuts
# Out:
#     index  Pozycja                                   Tytuł  \
# 0      51       52                      THE SOUND OF MUSIC
# 1       2        3    SGT PEPPER'S LONELY HEARTS CLUB BAND
# 2      20       21              BRIDGE OVER TROUBLED WATER
# 3       6        7               THE DARK SIDE OF THE MOON
# 4      41       42                           TUBULAR BELLS
# 5      45       46                           GREATEST HITS
# 6      18       19                         BAT OUT OF HELL
# 7      10       11                                 RUMOURS
# 8      46       47                                  GREASE
# 9      36       37                   THE WAR OF THE WORLDS
# 10      0        1                           GREATEST HITS
# 11      5        6                                THRILLER
# 12     15       16                                  LEGEND
# 13      7        8                        BROTHERS IN ARMS
# 14     50       51                               GRACELAND
# 15     35       36                         THE JOSHUA TREE
# 16     43       44                           TRACY CHAPMAN
# 17     38       39                           BUT SERIOUSLY
# 18     11       12               THE IMMACULATE COLLECTION
# 19     13       14                                   STARS
# 20     59       60                AUTOMATIC FOR THE PEOPLE
# 21      4        5          WHAT'S THE STORY MORNING GLORY
# 22     40       41                      JAGGED LITTLE PILL
# 23     28       29                                   SPICE
# 24     27       28                         TALK ON CORNERS
# 25     14       15                            COME ON OVER
# 26     17       18                             URBAN HYMNS
# 27     25       26                            WHITE LADDER
# 28     52       53        LADIES & GENTLEMEN - THE BEST OF
# 29     47       48                 I'VE BEEN EXPECTING YOU
# 30     42       43                             THE MAN WHO
# 31     24       25                                NO ANGEL
# 32     44       45                              PARACHUTES
# 33     54       55                 THE MARSHALL MATHERS LP
# 34     49       50                       COME AWAY WITH ME
# 35     37       38                         SCISSOR SISTERS
# 36     34       35                         HOPES AND FEARS
# 37     16       17                          BACK TO BEDLAM
# 38     58       59  NEVER FORGET - THE ULTIMATE COLLECTION
# 39     57       58                               EYES OPEN
# 40     12       13                           BACK TO BLACK
# 41     22       23                                  SPIRIT
# 42     32       33                       ONLY BY THE NIGHT
# 43     29       30                                THE FAME
# 44     23       24                              CRAZY LOVE
# 45      3        4                                      21
# 46     48       49                                       X
#
#                      Artysta   Rok
# 0    ORIGINAL CAST RECORDING  1965
# 1                    BEATLES  1967
# 2          SIMON & GARFUNKEL  1970
# 3                 PINK FLOYD  1973
# 4              MIKE OLDFIELD  1973
# 5                       ABBA  1975
# 6                  MEAT LOAF  1977
# 7              FLEETWOOD MAC  1977
# 8        ORIGINAL SOUNDTRACK  1977
# 9                 JEFF WAYNE  1978
# 10                     QUEEN  1981
# 11           MICHAEL JACKSON  1982
# 12  BOB MARLEY & THE WAILERS  1984
# 13              DIRE STRAITS  1985
# 14                PAUL SIMON  1986
# 15                        U2  1987
# 16             TRACY CHAPMAN  1988
# 17              PHIL COLLINS  1989
# 18                   MADONNA  1990
# 19                SIMPLY RED  1991
# 20                       REM  1992
# 21                     OASIS  1995
# 22         ALANIS MORISSETTE  1995
# 23               SPICE GIRLS  1996
# 24                     CORRS  1997
# 25              SHANIA TWAIN  1997
# 26                     VERVE  1997
# 27                DAVID GRAY  1998
# 28            GEORGE MICHAEL  1998
# 29           ROBBIE WILLIAMS  1998
# 30                    TRAVIS  1999
# 31                      DIDO  2000
# 32                  COLDPLAY  2000
# 33                    EMINEM  2000
# 34               NORAH JONES  2002
# 35           SCISSOR SISTERS  2004
# 36                     KEANE  2004
# 37               JAMES BLUNT  2004
# 38                 TAKE THAT  2005
# 39               SNOW PATROL  2006
# 40             AMY WINEHOUSE  2006
# 41               LEONA LEWIS  2007
# 42             KINGS OF LEON  2008
# 43                 LADY GAGA  2008
# 44             MICHAEL BUBLE  2009
# 45                     ADELE  2011
# 46                ED SHEERAN  2014

# %%
writer = pd.ExcelWriter("debuts_on_top.xlsx", engine='xlsxwriter')

# %%
debuts[['Tytuł','Artysta','Rok']].to_excel(writer, sheet_name='debuts', )
writer.close()

# %%
def second_way():
    '''not succesful'''
    debuts.sort_values(by = 'Artysta', inplace=True)
    debuts
    # debuts.set_index([pd.Index(debuts['Artysta'].to_list()), debuts.index],inplace=True)
    debuts.set_index([pd.Index(debuts['Artysta'].to_list()),debuts['Tytuł']],inplace=True)
    debuts.index.names = ['Artysta', 'Tytuł']
    return None
